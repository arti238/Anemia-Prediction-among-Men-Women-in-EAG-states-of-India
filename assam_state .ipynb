# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users//ARTI//Desktop//assam_dataset//combine.csv")

# %%
df.head()
# Out:
#   state_code district_code rural_urban           stratum     PSU_ID  \
# 0      ASSAM       BARPETA       Rural  population>=2000  1104095.0
# 1      ASSAM       BARPETA       Rural  population>=2000  1104307.0
# 2      ASSAM       BARPETA       Rural  population>=2000  1104275.0
# 3      ASSAM       BARPETA       Rural  population>=2000  1104520.0
# 4      ASSAM       BARPETA       Rural  population>=2000  1104276.0
#
#    ahs_house_unit  house_hold_no date_survey  test_salt_iodine  \
# 0            97.0            2.0  26-11-2014               7.0
# 1            97.0            2.0  26-11-2014               7.0
# 2           103.0            1.0  26-11-2014               7.0
# 3           103.0            1.0  26-11-2014               7.0
# 4           103.0            1.0  26-11-2014               7.0
#
#   record_code_iodine  ... day_or_mn_for_breast_feeding_cd  \
# 0   Less than 15 PPM  ...                             NaN
# ...

# %%
#to check non-null values  column wise
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137661 entries, 0 to 137660
# Data columns (total 53 columns):
# state_code                         137661 non-null object
# district_code                      137660 non-null object
# rural_urban                        137660 non-null object
# stratum                            137660 non-null object
# PSU_ID                             137660 non-null float64
# ahs_house_unit                     137660 non-null float64
# house_hold_no                      137660 non-null float64
# date_survey                        137660 non-null object
# test_salt_iodine                   137660 non-null float64
# record_code_iodine                 137660 non-null object
# record_code_iodine_reason          29 non-null object
# sl_no                              137660 non-null float64
# Sex                                137660 non-null object
# usual_residance                    137660 non-null object
# ...

# %%
#to check number of Nan values each column wise
df.isnull().sum()
# Out:
# state_code                              0
# district_code                           1
# rural_urban                             1
# stratum                                 1
# PSU_ID                                  1
# ahs_house_unit                          1
# house_hold_no                           1
# date_survey                             1
# test_salt_iodine                        1
# record_code_iodine                      1
# record_code_iodine_reason          137632
# sl_no                                   1
# Sex                                     1
# usual_residance                         1
# usual_residance_Reason             130479
# identification_code                   246
# Age_Code                                1
# Age                                    12
# date_of_birth                           1
# month_of_birth                          1
# year_of_birth                           1
# Weight_measured                     10674
# ...

# %%
df.shape
# Out:
# (137661, 53)

# %%
#to check object type column wise
df.dtypes
# Out:
# state_code                          object
# district_code                       object
# rural_urban                         object
# stratum                             object
# PSU_ID                             float64
# ahs_house_unit                     float64
# house_hold_no                      float64
# date_survey                         object
# test_salt_iodine                   float64
# record_code_iodine                  object
# record_code_iodine_reason           object
# sl_no                              float64
# Sex                                 object
# usual_residance                     object
# usual_residance_Reason              object
# identification_code                float64
# Age_Code                            object
# Age                                float64
# date_of_birth                      float64
# month_of_birth                     float64
# year_of_birth                      float64
# Weight_measured                     object
# ...

# %%
# Drop unwanted variables
df = df.drop(['PSU_ID', 'ahs_house_unit', 'house_hold_no','date_survey','record_code_iodine', 'record_code_iodine_reason', 'sl_no','usual_residance_Reason', 'identification_code','date_of_birth', 'month_of_birth', 'year_of_birth','Weight_measured','Length_height_measured',
       'length_height_code','Haemoglobin_test','Haemoglobin','fasting_blood_glucose'], axis = 1)
print(df)
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 2           ASSAM       BARPETA       Rural  population>=2000
# 3           ASSAM       BARPETA       Rural  population>=2000
# 4           ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137657      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
# 137660                     NaN         NaN               NaN
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 2           ASSAM       BARPETA       Rural  population>=2000
# 3           ASSAM       BARPETA       Rural  population>=2000
# 4           ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137657      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
# 137660                     NaN         NaN               NaN
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
df[['Haemoglobin_level']]
# Out:
#         Haemoglobin_level
# 0                     8.0
# 1                    15.0
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 137656                9.5
# 137657                NaN
# 137658               11.0
# 137659               11.0
# 137660                NaN
#
# [137661 rows x 1 columns]

# %%
#Drop rows where Haemoglobin_level is null
df=df.dropna(subset = ["Haemoglobin_level"],axis=0)

# %%
df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
df[['Age','Age_Code']]
# Out:
#          Age Age_Code
# 0       37.0     Year
# 1       17.0     Year
# 7       47.0     Year
# 10      33.0     Year
# 11      25.0     Year
# ...      ...      ...
# 137654  18.0     Year
# 137655  23.0     Year
# 137656  31.0     Year
# 137658   1.0     Year
# 137659  29.0     Year
#
# [88312 rows x 2 columns]

# %%
df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
#dropping days wise age columns 
df.drop(df.loc[df['Age_Code']=='Days'].index)
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
df[['Age_Code','Age']]
# Out:
#        Age_Code   Age
# 0          Year  37.0
# 1          Year  17.0
# 7          Year  47.0
# 10         Year  33.0
# 11         Year  25.0
# ...         ...   ...
# 137654     Year  18.0
# 137655     Year  23.0
# 137656     Year  31.0
# 137658     Year   1.0
# 137659     Year  29.0
#
# [88312 rows x 2 columns]

# %%
# To change Age_code  months into years

# Copy dataframe data to df1 where age _code in months
df1 = df[df['Age_Code'] =='Months']
print(df1)
# Out:
#        state_code district_code rural_urban              stratum  \
# 13826       ASSAM        CACHAR       Rural  200<population<2000
# 14129       ASSAM        CACHAR       Rural     population>=2000
# 14132       ASSAM        CACHAR       Rural     population>=2000
# 14155       ASSAM        CACHAR       Rural     population>=2000
# 15041       ASSAM        CACHAR       Rural     population>=2000
# ...           ...           ...         ...                  ...
# 134591      ASSAM      TINSUKIA       Rural     population>=2000
# 135698      ASSAM      TINSUKIA       Rural  200<population<2000
# 135700      ASSAM      TINSUKIA       Rural  200<population<2000
# 136229      ASSAM      TINSUKIA       Rural     population>=2000
# 137394      ASSAM      TINSUKIA       Urban                Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 13826                7.0  Female             YES   Months  10.0           7.2
# ...

# %%
df1[['Age','Age_Code']]
# Out:
#          Age Age_Code
# 13826   10.0   Months
# 14129    1.0   Months
# 14132    7.0   Months
# 14155    8.0   Months
# 15041   10.0   Months
# ...      ...      ...
# 134591  11.0   Months
# 135698  11.0   Months
# 135700   6.0   Months
# 136229  11.0   Months
# 137394   7.0   Months
#
# [126 rows x 2 columns]

# %%
#Convert Age months to years
df1['Age']=df1['Age']/12

# %%
df1['Age_Code']='Year'

# %%
#checking dataframe after conversion 
df1[['Age','Age_Code']]
# Out:
#              Age Age_Code
# 13826   0.833333     Year
# 14129   0.083333     Year
# 14132   0.583333     Year
# 14155   0.666667     Year
# 15041   0.833333     Year
# ...          ...      ...
# 134591  0.916667     Year
# 135698  0.916667     Year
# 135700  0.500000     Year
# 136229  0.916667     Year
# 137394  0.583333     Year
#
# [126 rows x 2 columns]

# %%
#Create a new dataframe df2 here age_code is year 
df2=df[df['Age_Code'] == 'Year']
print(df2)
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
#concatenate df2 and df1 in new dataframe df3
df3 = pd.concat([df2,df1])

# %%
df3
# Out:
#        state_code district_code rural_urban              stratum  \
# 0           ASSAM       BARPETA       Rural     population>=2000
# 1           ASSAM       BARPETA       Rural     population>=2000
# 7           ASSAM       BARPETA       Rural     population>=2000
# 10          ASSAM       BARPETA       Rural     population>=2000
# 11          ASSAM       BARPETA       Rural     population>=2000
# ...           ...           ...         ...                  ...
# 134591      ASSAM      TINSUKIA       Rural     population>=2000
# 135698      ASSAM      TINSUKIA       Rural  200<population<2000
# 135700      ASSAM      TINSUKIA       Rural  200<population<2000
# 136229      ASSAM      TINSUKIA       Rural     population>=2000
# 137394      ASSAM      TINSUKIA       Urban                Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code        Age  \
# 0                    7.0  Female             YES     Year  37.000000
# ...

# %%
df3['Age_Code'].value_counts()
# Out:
# Year    88312
# Name: Age_Code, dtype: int64

# %%
# selecting rows based on condition(age range between 6months-3years) 
child_df=df3[(df3['Age'] >=0.5) &(df3['Age']<=3)]

# %%
child_df
# Out:
#        state_code district_code rural_urban              stratum  \
# 1319        ASSAM       BARPETA       Urban                Urban
# 4169        ASSAM       BARPETA       Rural     population>=2000
# 4813        ASSAM       BARPETA       Rural     population>=2000
# 5935        ASSAM       BARPETA       Rural     population>=2000
# 5937        ASSAM       BARPETA       Rural     population>=2000
# ...           ...           ...         ...                  ...
# 134591      ASSAM      TINSUKIA       Rural     population>=2000
# 135698      ASSAM      TINSUKIA       Rural  200<population<2000
# 135700      ASSAM      TINSUKIA       Rural  200<population<2000
# 136229      ASSAM      TINSUKIA       Rural     population>=2000
# 137394      ASSAM      TINSUKIA       Urban                Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code       Age  \
# 1319                 7.0    Male             YES     Year  3.000000
# ...

# %%
# selecting rows age range 4-18years
young_df=df3[(df3['Age'] >=4) &(df3['Age']<18)]

# %%
young_df
# Out:
#        state_code district_code rural_urban              stratum  \
# 1           ASSAM       BARPETA       Rural     population>=2000
# 18          ASSAM       BARPETA       Rural     population>=2000
# 21          ASSAM       BARPETA       Rural     population>=2000
# 26          ASSAM       BARPETA       Rural     population>=2000
# 28          ASSAM       BARPETA       Rural     population>=2000
# ...           ...           ...         ...                  ...
# 137606      ASSAM      TINSUKIA       Urban                Urban
# 137634      ASSAM      TINSUKIA       Urban                Urban
# 137640      ASSAM      TINSUKIA       Rural  200<population<2000
# 137641      ASSAM      TINSUKIA       Rural  200<population<2000
# 137642      ASSAM      TINSUKIA       Rural  200<population<2000
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 1                    7.0    Male             YES     Year  17.0     25.600000
# ...

# %%
# selecting rows age range 18-110 years
old_df=df3[(df3['Age'] >=18)&(df3['Age']<=110)]

# %%
old_df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# 19          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137653      ASSAM      TINSUKIA       Urban             Urban
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
child_df
# Out:
#        state_code district_code rural_urban              stratum  \
# 1319        ASSAM       BARPETA       Urban                Urban
# 4169        ASSAM       BARPETA       Rural     population>=2000
# 4813        ASSAM       BARPETA       Rural     population>=2000
# 5935        ASSAM       BARPETA       Rural     population>=2000
# 5937        ASSAM       BARPETA       Rural     population>=2000
# ...           ...           ...         ...                  ...
# 134591      ASSAM      TINSUKIA       Rural     population>=2000
# 135698      ASSAM      TINSUKIA       Rural  200<population<2000
# 135700      ASSAM      TINSUKIA       Rural  200<population<2000
# 136229      ASSAM      TINSUKIA       Rural     population>=2000
# 137394      ASSAM      TINSUKIA       Urban                Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code       Age  \
# 1319                 7.0    Male             YES     Year  3.000000
# ...

# %%
# Haemoglobin_level plotting for child_df

# %%
child_df['Haemoglobin_level'].plot.hist(bins=12, alpha=0.5)
plt.title('HB_level of Children')
plt.xlabel('HB_level')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of weight_in_kg for child_df

# %%
child_df['Weight_in_kg']
# Out:
# 1319      12.4
# 4169      12.0
# 4813      13.0
# 5935       7.0
# 5937      13.0
#           ...
# 134591     6.3
# 135698     8.3
# 135700     9.0
# 136229     9.5
# 137394     7.8
# Name: Weight_in_kg, Length: 2475, dtype: float64

# %%
child_df['Weight_in_kg'].plot.hist(bins=12, alpha=0.5)
plt.title('weight of Children')
plt.xlabel('weight')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
child_df[['Weight_in_kg']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2475 entries, 1319 to 137394
# Data columns (total 1 columns):
# Weight_in_kg    2459 non-null float64
# dtypes: float64(1)
# memory usage: 38.7 KB

# %%
# plotting of length_height_cm for child_df

# %%
child_df['Length_height_cm']
# Out:
# 1319      98.599998
# 4169      90.000000
# 4813      92.000000
# 5935      72.000000
# 5937      87.400002
#             ...
# 134591    66.000000
# 135698    74.699997
# 135700    72.099998
# 136229    75.400002
# 137394    70.500000
# Name: Length_height_cm, Length: 2475, dtype: float64

# %%
child_df['Length_height_cm'].plot.hist(bins=12, alpha=0.5)
plt.title('length_height_cm_plotting')
plt.xlabel('lenth_height_cm')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# plotting of is_cur_breast_feeding
child_df['is_cur_breast_feeding'].dropna()
# Out:
# 4813       NO
# 5935      YES
# 8322      YES
# 9400       NO
# 9466       NO
#          ...
# 134591    YES
# 135698    YES
# 135700    YES
# 136229    YES
# 137394    YES
# Name: is_cur_breast_feeding, Length: 1485, dtype: object

# %%
#Mapping the labels non-numeric to numeric

# %%
child_df['is_cur_breast_feeding'] = child_df['is_cur_breast_feeding'].map({'YES' : 1,'NO' : 2})

# %%
child_df['is_cur_breast_feeding'].plot.hist(bins=12, alpha=0.5)
plt.title('length_height_cm_plotting')
plt.xlabel('lenth_height_cm')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# plotting of day_or_mn_for_breast_feeding
child_df['day_or_month_for_breast_feeding'].dropna()
# Out:
# 4813      6.0
# 5935      5.0
# 8322      7.0
# 9400      6.0
# 9466      5.0
#          ...
# 134591    5.0
# 135698    6.0
# 135700    5.0
# 136229    5.0
# 137394    5.0
# Name: day_or_month_for_breast_feeding, Length: 1485, dtype: float64

# %%
child_df['day_or_month_for_breast_feeding'].plot.hist(bins=12, alpha=0.5)
plt.title('day_or_month_for_breast_feeding plotting')
plt.xlabel('day_or_month_for_breast_feeding')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of Water_month for child_df
child_df['water_month'].dropna()
# Out:
# 4813      7.0
# 5935      6.0
# 8322      7.0
# 9400      6.0
# 9466      5.0
#          ...
# 134591    6.0
# 135698    6.0
# 135700    6.0
# 136229    6.0
# 137394    6.0
# Name: water_month, Length: 1484, dtype: float64

# %%
child_df['water_month'].plot.hist(bins=12, alpha=0.5)
plt.title('water_month plotting')
plt.xlabel('water_month')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of ani_milk_month for child_df
child_df['ani_milk_month'].dropna()
# Out:
# 4813      7.0
# 5935      6.0
# 8322      7.0
# 9466      5.0
# 12549     5.0
#          ...
# 134591    6.0
# 135698    7.0
# 135700    6.0
# 136229    7.0
# 137394    6.0
# Name: ani_milk_month, Length: 1483, dtype: float64

# %%
child_df['ani_milk_month'].plot.hist(bins=12, alpha=0.5)
plt.title('ani_milk_month plotting')
plt.xlabel('ani_milk_month')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# plotting of semisolid_month_or_day
child_df['semisolid_month_or_day'].dropna()
# Out:
# 4813       7.0
# 5935       6.0
# 8322      10.0
# 9400       6.0
# 9466      10.0
#           ...
# 134591     7.0
# 135698     7.0
# 135700     6.0
# 136229     7.0
# 137394     6.0
# Name: semisolid_month_or_day, Length: 1484, dtype: float64

# %%
child_df['semisolid_month_or_day'].plot.hist(bins=12, alpha=0.5)
plt.title('semisolid_month_or_day plotting')
plt.xlabel('semisolid_month_or_day')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of solid_month for child_df
child_df['solid_month'].dropna()
# Out:
# 4813       8.0
# 5935       7.0
# 8322      16.0
# 9400       9.0
# 9466      12.0
#           ...
# 134591     8.0
# 135698     7.0
# 135700     6.0
# 136229     7.0
# 137394     0.0
# Name: solid_month, Length: 1484, dtype: float64

# %%
child_df['solid_month'].plot.hist(bins=12, alpha=0.5)
plt.title('solid_month plotting')
plt.xlabel('solid_month')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of vegetables_month_or_day
child_df['vegetables_month_or_day'].dropna()
# Out:
# 4813       7.0
# 5935       6.0
# 8322      16.0
# 9400      13.0
# 9466      12.0
#           ...
# 134591     7.0
# 135698     8.0
# 135700     6.0
# 136229     7.0
# 137394     0.0
# Name: vegetables_month_or_day, Length: 1484, dtype: float64

# %%
child_df['vegetables_month_or_day'].plot.hist(bins=12, alpha=0.5)
plt.title('vegetables_month_or_day plotting')
plt.xlabel('vegetables_month_or_day')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
corr=child_df.corr()[['Weight_in_kg','Haemoglobin_level','is_cur_breast_feeding',
                     'day_or_month_for_breast_feeding','water_month','ani_milk_month','semisolid_month_or_day','solid_month','vegetables_month_or_day']]

# %%
corr
# Out:
#                                  Weight_in_kg  Haemoglobin_level  \
# test_salt_iodine                     0.004114          -0.011366
# Age                                  0.314345           0.075297
# Weight_in_kg                         1.000000           0.027318
# Length_height_cm                     0.373962           0.108575
# Haemoglobin_level                    0.027318           1.000000
# BP_systolic                               NaN                NaN
# BP_systolic_2_reading                     NaN                NaN
# BP_Diastolic                              NaN                NaN
# BP_Diastolic_2reading                     NaN                NaN
# Pulse_rate                                NaN                NaN
# Pulse_rate_2_reading                      NaN                NaN
# fasting_blood_glucose_mg_dl               NaN                NaN
# duration_pregnanacy                       NaN                NaN
# ...

# %%
#Drop the columns where not coorelation between the variables

# %%
data_correlated = corr.drop(['BP_systolic','BP_systolic_2_reading','BP_Diastolic','BP_Diastolic_2reading','Pulse_rate','Pulse_rate_2_reading',
                             'fasting_blood_glucose_mg_dl','duration_pregnanacy'])

# %%
#correlatio among variables of child_df
data_correlated
# Out:
#                                  Weight_in_kg  Haemoglobin_level  \
# test_salt_iodine                     0.004114          -0.011366
# Age                                  0.314345           0.075297
# Weight_in_kg                         1.000000           0.027318
# Length_height_cm                     0.373962           0.108575
# Haemoglobin_level                    0.027318           1.000000
# is_cur_breast_feeding                0.030658          -0.006390
# day_or_month_for_breast_feeding     -0.010424          -0.049800
# water_month                          0.041241          -0.024056
# ani_milk_month                       0.016960          -0.033823
# semisolid_month_or_day               0.062971           0.039402
# solid_month                          0.088119           0.077144
# vegetables_month_or_day              0.104845           0.063563
# illness_duration                    -0.063501           0.102442
#
# ...

# %%
young_df
# Out:
#        state_code district_code rural_urban              stratum  \
# 1           ASSAM       BARPETA       Rural     population>=2000
# 18          ASSAM       BARPETA       Rural     population>=2000
# 21          ASSAM       BARPETA       Rural     population>=2000
# 26          ASSAM       BARPETA       Rural     population>=2000
# 28          ASSAM       BARPETA       Rural     population>=2000
# ...           ...           ...         ...                  ...
# 137606      ASSAM      TINSUKIA       Urban                Urban
# 137634      ASSAM      TINSUKIA       Urban                Urban
# 137640      ASSAM      TINSUKIA       Rural  200<population<2000
# 137641      ASSAM      TINSUKIA       Rural  200<population<2000
# 137642      ASSAM      TINSUKIA       Rural  200<population<2000
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 1                    7.0    Male             YES     Year  17.0     25.600000
# ...

# %% [markdown]
# #plotting of young_df columns

# %%
# Plotting of Haemoglobin_level for young_df

# %%
young_df['Haemoglobin_level'].plot.hist(bins=12, alpha=0.5)
plt.title('HB_level of Children')
plt.xlabel('HB_level')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of weight_in_kg
young_df['Weight_in_kg'].dropna()
# Out:
# 1         25.600000
# 18        42.000000
# 21        47.000000
# 26        36.000000
# 28        33.099998
#             ...
# 137606    50.599998
# 137634    15.400000
# 137640    42.299999
# 137641    17.200001
# 137642    21.299999
# Name: Weight_in_kg, Length: 22193, dtype: float64

# %%
young_df['Weight_in_kg'].plot.hist(bins=12, alpha=0.5)
plt.title('Weight_in_kg plotting')
plt.xlabel('Weight_in_kg')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of length_height_cm
young_df['Length_height_cm'].dropna()
# Out:
# 1         160.30000
# 18        148.30000
# 21        149.30000
# 26        144.20000
# 28        141.60001
#             ...
# 137606    165.10001
# 137634    106.40000
# 137640    129.30000
# 137641    147.50000
# 137642    126.00000
# Name: Length_height_cm, Length: 22217, dtype: float64

# %%
young_df['Length_height_cm'].plot.hist(bins=12, alpha=0.5)
plt.title('Length_height_cm plotting')
plt.xlabel('Length_height_cm')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting of Marital_status
young_df['Marital_status'].dropna()
# Out:
# 18        Never married
# 21        Never married
# 45        Never married
# 74        Never married
# 82        Never married
#               ...
# 137495    Never married
# 137511    Never married
# 137527    Never married
# 137602    Never married
# 137605    Never married
# Name: Marital_status, Length: 2666, dtype: object

# %%
young_df['Marital_status'] = young_df['Marital_status'].map({'Married and Gauna Performed' : 1,'Never married': 2,
                                                             'Married but Gauna not performed' : 3,'Widow': 4,'Separated' : 5,
                                                            'Divorced' : 6,'Remmaried':7,'Not Stated':8,'NaN' : -1})

# %%
young_df['Marital_status'].plot.hist(bins=12, alpha=0.5)
plt.title('Marital_status plotting')
plt.xlabel('Marital_status')
plt.ylabel('No. of Children')
# Out:
# Text(0, 0.5, 'No. of Children')

# %%
# Plotting Of duration_pregnancy
young_df['duration_pregnanacy'].dropna()
# Out:
# 9596     7.0
# 13030    3.0
# 18203    4.0
# 23731    2.0
# 61720    1.0
# 78577    2.0
# 78669    2.0
# 80377    2.0
# 99584    6.0
# Name: duration_pregnanacy, dtype: float64

# %%
young_df['duration_pregnanacy'].plot.hist(bins = 12,alpha = 0.5)
plt.title('duration_pregnanacy')
plt.xlabel('duration_pregnanacy')
# Out:
# Text(0.5, 0, 'duration_pregnanacy')

# %%
#correlation among variables of young_df(4-18years)
corr=young_df.corr()[['Haemoglobin_level','Weight_in_kg','Length_height_cm','Marital_status','gauna_perfor_not_perfor',
                      'duration_pregnanacy','illness_duration']]

# %%
corr
# Out:
#                                  Haemoglobin_level  Weight_in_kg  \
# test_salt_iodine                         -0.016304      0.027212
# Age                                       0.056612      0.772231
# Weight_in_kg                              0.065946      1.000000
# Length_height_cm                          0.068639      0.796768
# Haemoglobin_level                         1.000000      0.065946
# BP_systolic                              -0.483675      0.316576
# BP_systolic_2_reading                    -0.417064      0.148550
# BP_Diastolic                             -0.241929      0.131114
# BP_Diastolic_2reading                    -0.128866     -0.038585
# Pulse_rate                               -0.367090      0.354866
# Pulse_rate_2_reading                     -0.605930     -0.045037
# fasting_blood_glucose_mg_dl               0.586321     -0.155552
# Marital_status                            0.020098      0.016936
# ...

# %%
#Drop the columns where not coorelation between the variables 
data_correlated = corr.drop(['gauna_perfor_not_perfor','day_or_month_for_breast_feeding','water_month','ani_milk_month','semisolid_month_or_day',
                             'solid_month','vegetables_month_or_day'])

# %%
data_correlated
# Out:
#                              Haemoglobin_level  Weight_in_kg  \
# test_salt_iodine                     -0.016304      0.027212
# Age                                   0.056612      0.772231
# Weight_in_kg                          0.065946      1.000000
# Length_height_cm                      0.068639      0.796768
# Haemoglobin_level                     1.000000      0.065946
# BP_systolic                          -0.483675      0.316576
# BP_systolic_2_reading                -0.417064      0.148550
# BP_Diastolic                         -0.241929      0.131114
# BP_Diastolic_2reading                -0.128866     -0.038585
# Pulse_rate                           -0.367090      0.354866
# Pulse_rate_2_reading                 -0.605930     -0.045037
# fasting_blood_glucose_mg_dl           0.586321     -0.155552
# Marital_status                        0.020098      0.016936
# duration_pregnanacy                  -0.297246      0.351849
# ...

# %%
old_df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# 19          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137653      ASSAM      TINSUKIA       Urban             Urban
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %% [markdown]
# #each column wise plotting for young_df

# %%
# Plotting of Haemoglobin_level for old_df

# %%
old_df['Haemoglobin_level'].plot.hist(bins=12, alpha=0.5)
plt.title('HB_level')
plt.xlabel('HB_level')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
# Plotting of weight_in_kg
old_df['Weight_in_kg'].dropna()
# Out:
# 0         48.099998
# 7         49.200001
# 10        53.599998
# 11        47.000000
# 19        49.500000
#             ...
# 137653    53.400002
# 137654    40.599998
# 137655    65.199997
# 137656    42.200001
# 137659    46.200001
# Name: Weight_in_kg, Length: 62488, dtype: float64

# %%
old_df['Weight_in_kg'].plot.hist(bins=12, alpha=0.5)
plt.title('Weight_in_kg plotting')
plt.xlabel('Weight_in_kg')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
## Plotting of length_height_cm
old_df['Length_height_cm'].dropna()
# Out:
# 0         147.89999
# 7         147.70000
# 10        164.10001
# 11        147.80000
# 19        160.70000
#             ...
# 137653    151.00000
# 137654    145.50000
# 137655    146.00000
# 137656    145.10001
# 137659    143.80000
# Name: Length_height_cm, Length: 62484, dtype: float64

# %%
old_df['Length_height_cm'].plot.hist(bins=12, alpha=0.5)
plt.title('Length_height_cm plotting')
plt.xlabel('Length_height_cm')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
#plotting of BP_systolic
old_df['BP_systolic'].dropna()
# Out:
# 0         124.0
# 7         134.0
# 10        128.0
# 11        119.0
# 19        141.0
#           ...
# 137653    124.0
# 137654    138.0
# 137655    137.0
# 137656    130.0
# 137659    105.0
# Name: BP_systolic, Length: 62548, dtype: float64

# %%
old_df['BP_systolic'].plot.hist(bins=12, alpha=0.5)
plt.title('BP_systolic plotting')
plt.xlabel('BP_systolic')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
#plotting of column BP_systolic_2_reading
old_df['BP_systolic_2_reading'].dropna()
# Out:
# 0         127.0
# 7         132.0
# 10        125.0
# 11        114.0
# 19        144.0
#           ...
# 137653    120.0
# 137654    130.0
# 137655    130.0
# 137656    124.0
# 137659    100.0
# Name: BP_systolic_2_reading, Length: 62522, dtype: float64

# %%
old_df['BP_systolic_2_reading'].plot.hist(bins=12, alpha=0.5)
plt.title('BP_systolic_2_reading plotting')
plt.xlabel('BP_systolic_2_reading')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
#plotting of column BP_diastolic
old_df['BP_Diastolic'].dropna()
# Out:
# 0         66.0
# 7         90.0
# 10        90.0
# 11        69.0
# 19        83.0
#           ...
# 137653    93.0
# 137654    81.0
# 137655    79.0
# 137656    86.0
# 137659    65.0
# Name: BP_Diastolic, Length: 62548, dtype: float64

# %%
old_df['BP_Diastolic'].plot.hist(bins=12, alpha=0.5)
plt.title('BP_Diastolic plotting')
plt.xlabel('BP_Diastolic')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
#Pulse rate plotting
old_df['Pulse_rate'].dropna()
# Out:
# 0         74.0
# 7         98.0
# 10        74.0
# 11        93.0
# 19        86.0
#           ...
# 137653    80.0
# 137654    78.0
# 137655    84.0
# 137656    75.0
# 137659    82.0
# Name: Pulse_rate, Length: 62543, dtype: float64

# %%
old_df['Pulse_rate'].plot.hist(bins=12, alpha=0.5)
plt.title('Pulse_rate plotting')
plt.xlabel('Pulse_rate')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
#correlation among variables of old_df(18-18+years)
corr=young_df.corr()[['Haemoglobin_level','Weight_in_kg','Length_height_cm','BP_systolic','BP_systolic_2_reading','Marital_status',
                      'gauna_perfor_not_perfor','Pulse_rate','Pulse_rate_2_reading',
                      'fasting_blood_glucose_mg_dl','duration_pregnanacy']]

# %%
corr
# Out:
#                                  Haemoglobin_level  Weight_in_kg  \
# test_salt_iodine                         -0.016304      0.027212
# Age                                       0.056612      0.772231
# Weight_in_kg                              0.065946      1.000000
# Length_height_cm                          0.068639      0.796768
# Haemoglobin_level                         1.000000      0.065946
# BP_systolic                              -0.483675      0.316576
# BP_systolic_2_reading                    -0.417064      0.148550
# BP_Diastolic                             -0.241929      0.131114
# BP_Diastolic_2reading                    -0.128866     -0.038585
# Pulse_rate                               -0.367090      0.354866
# Pulse_rate_2_reading                     -0.605930     -0.045037
# fasting_blood_glucose_mg_dl               0.586321     -0.155552
# Marital_status                            0.020098      0.016936
# ...

# %%
#Drop the columns where not coorelation between the variables 
data_correlated = corr.drop(['day_or_month_for_breast_feeding','water_month','ani_milk_month','semisolid_month_or_day','solid_month',
                             'vegetables_month_or_day','gauna_perfor_not_perfor'])

# %%
data_correlated
# Out:
#                              Haemoglobin_level  Weight_in_kg  \
# test_salt_iodine                     -0.016304      0.027212
# Age                                   0.056612      0.772231
# Weight_in_kg                          0.065946      1.000000
# Length_height_cm                      0.068639      0.796768
# Haemoglobin_level                     1.000000      0.065946
# BP_systolic                          -0.483675      0.316576
# BP_systolic_2_reading                -0.417064      0.148550
# BP_Diastolic                         -0.241929      0.131114
# BP_Diastolic_2reading                -0.128866     -0.038585
# Pulse_rate                           -0.367090      0.354866
# Pulse_rate_2_reading                 -0.605930     -0.045037
# fasting_blood_glucose_mg_dl           0.586321     -0.155552
# Marital_status                        0.020098      0.016936
# duration_pregnanacy                  -0.297246      0.351849
# ...
