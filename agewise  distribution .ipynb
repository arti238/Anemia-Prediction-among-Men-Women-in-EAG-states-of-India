# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users//ARTI//Desktop//assam_dataset//combine.csv")
# Out:
# C:\Users\ARTI\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   state_code district_code rural_urban           stratum     PSU_ID  \
# 0      ASSAM       BARPETA       Rural  population>=2000  1104095.0
# 1      ASSAM       BARPETA       Rural  population>=2000  1104307.0
# 2      ASSAM       BARPETA       Rural  population>=2000  1104275.0
# 3      ASSAM       BARPETA       Rural  population>=2000  1104520.0
# 4      ASSAM       BARPETA       Rural  population>=2000  1104276.0
#
#    ahs_house_unit  house_hold_no date_survey  test_salt_iodine  \
# 0            97.0            2.0  26-11-2014               7.0
# 1            97.0            2.0  26-11-2014               7.0
# 2           103.0            1.0  26-11-2014               7.0
# 3           103.0            1.0  26-11-2014               7.0
# 4           103.0            1.0  26-11-2014               7.0
#
#   record_code_iodine  ... day_or_mn_for_breast_feeding_cd  \
# 0   Less than 15 PPM  ...                             NaN
# ...

# %%
#to check non-null values column wise 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137661 entries, 0 to 137660
# Data columns (total 53 columns):
# state_code                         137661 non-null object
# district_code                      137660 non-null object
# rural_urban                        137660 non-null object
# stratum                            137660 non-null object
# PSU_ID                             137660 non-null float64
# ahs_house_unit                     137660 non-null float64
# house_hold_no                      137660 non-null float64
# date_survey                        137660 non-null object
# test_salt_iodine                   137660 non-null float64
# record_code_iodine                 137660 non-null object
# record_code_iodine_reason          29 non-null object
# sl_no                              137660 non-null float64
# Sex                                137660 non-null object
# usual_residance                    137660 non-null object
# ...

# %%
#to check number of Nan values each column wise
df.isnull().sum()
# Out:
# state_code                              0
# district_code                           1
# rural_urban                             1
# stratum                                 1
# PSU_ID                                  1
# ahs_house_unit                          1
# house_hold_no                           1
# date_survey                             1
# test_salt_iodine                        1
# record_code_iodine                      1
# record_code_iodine_reason          137632
# sl_no                                   1
# Sex                                     1
# usual_residance                         1
# usual_residance_Reason             130479
# identification_code                   246
# Age_Code                                1
# Age                                    12
# date_of_birth                           1
# month_of_birth                          1
# year_of_birth                           1
# Weight_measured                     10674
# ...

# %%
df.shape
# Out:
# (137661, 53)

# %%
#to check object type column wise
df.dtypes
# Out:
# state_code                          object
# district_code                       object
# rural_urban                         object
# stratum                             object
# PSU_ID                             float64
# ahs_house_unit                     float64
# house_hold_no                      float64
# date_survey                         object
# test_salt_iodine                   float64
# record_code_iodine                  object
# record_code_iodine_reason           object
# sl_no                              float64
# Sex                                 object
# usual_residance                     object
# usual_residance_Reason              object
# identification_code                float64
# Age_Code                            object
# Age                                float64
# date_of_birth                      float64
# month_of_birth                     float64
# year_of_birth                      float64
# Weight_measured                     object
# ...

# %%
# Drop unwanted variables
df = df.drop(['PSU_ID', 'ahs_house_unit', 'house_hold_no','date_survey','record_code_iodine', 'record_code_iodine_reason', 'sl_no','usual_residance_Reason', 'identification_code','date_of_birth', 'month_of_birth', 'year_of_birth','Weight_measured','Length_height_measured',
       'length_height_code','Haemoglobin_test','Haemoglobin','fasting_blood_glucose'], axis = 1)
print(df)
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 2           ASSAM       BARPETA       Rural  population>=2000
# 3           ASSAM       BARPETA       Rural  population>=2000
# 4           ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137657      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
# 137660                     NaN         NaN               NaN
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
df
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 2           ASSAM       BARPETA       Rural  population>=2000
# 3           ASSAM       BARPETA       Rural  population>=2000
# 4           ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137657      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
# 137660                     NaN         NaN               NaN
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
 df[['Haemoglobin_level']]
# Out:
#         Haemoglobin_level
# 0                     8.0
# 1                    15.0
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 137656                9.5
# 137657                NaN
# 137658               11.0
# 137659               11.0
# 137660                NaN
#
# [137661 rows x 1 columns]

# %%
#Drop rows where Haemoglobin_level is null
df1 = df.dropna(subset = ["Haemoglobin_level"],axis=0)
print(df1)
# Out:
#        state_code district_code rural_urban           stratum  \
# 0           ASSAM       BARPETA       Rural  population>=2000
# 1           ASSAM       BARPETA       Rural  population>=2000
# 7           ASSAM       BARPETA       Rural  population>=2000
# 10          ASSAM       BARPETA       Rural  population>=2000
# 11          ASSAM       BARPETA       Rural  population>=2000
# ...           ...           ...         ...               ...
# 137654      ASSAM      TINSUKIA       Urban             Urban
# 137655      ASSAM      TINSUKIA       Urban             Urban
# 137656      ASSAM      TINSUKIA       Urban             Urban
# 137658      ASSAM      TINSUKIA       Urban             Urban
# 137659      ASSAM      TINSUKIA       Urban             Urban
#
#         test_salt_iodine     Sex usual_residance Age_Code   Age  Weight_in_kg  \
# 0                    7.0  Female             YES     Year  37.0     48.099998
# ...

# %%
#to check nan values column wise
df1.isnull().sum()
# Out:
# state_code                             0
# district_code                          0
# rural_urban                            0
# stratum                                0
# test_salt_iodine                       0
# Sex                                    0
# usual_residance                        0
# Age_Code                               0
# Age                                    0
# Weight_in_kg                        1162
# Length_height_cm                    1162
# Haemoglobin_level                      0
# BP_systolic                        25757
# BP_systolic_2_reading              25783
# BP_Diastolic                       25757
# BP_Diastolic_2reading              25786
# Pulse_rate                         25762
# Pulse_rate_2_reading               25792
# Diabetes_test                      25092
# fasting_blood_glucose_mg_dl        25834
# Marital_status                     60218
# gauna_perfor_not_perfor            69994
# duration_pregnanacy                85699
# ...

# %%
data = df[['Age','Age_Code']]
print(data)
# Out:
#          Age Age_Code
# 0       37.0     Year
# 1       17.0     Year
# 2       20.0     Year
# 3        9.0   Months
# 4       19.0     Year
# ...      ...      ...
# 137656  31.0     Year
# 137657  24.0     Year
# 137658   1.0     Year
# 137659  29.0     Year
# 137660   NaN      NaN
#
# [137661 rows x 2 columns]

# %%
#dropping days wise age columns 
data = data.drop(data.loc[data['Age_Code']=='Days'].index)
print(data)
# Out:
#          Age Age_Code
# 0       37.0     Year
# 1       17.0     Year
# 2       20.0     Year
# 3        9.0   Months
# 4       19.0     Year
# ...      ...      ...
# 137656  31.0     Year
# 137657  24.0     Year
# 137658   1.0     Year
# 137659  29.0     Year
# 137660   NaN      NaN
#
# [137616 rows x 2 columns]

# %%
# To change Age months into years

# Copy dataframe data to df2 where age _code in months
df2 = data[data['Age_Code'] =='Months']

# %%
df2[['Age','Age_Code']]
# Out:
#          Age Age_Code
# 3        9.0   Months
# 15       7.0   Months
# 23       5.0   Months
# 132     11.0   Months
# 438     11.0   Months
# ...      ...      ...
# 137398   3.0   Months
# 137399   6.0   Months
# 137404   9.0   Months
# 137651   5.0   Months
# 137652   2.0   Months
#
# [1118 rows x 2 columns]

# %%
#Convert Age months to years
df2['Age']=df2['Age']/12
# Out:
# C:\Users\ARTI\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2['Age_Code']='Year'
# Out:
# C:\Users\ARTI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#checking dataframe after conversion 
df2[['Age','Age_Code']]
# Out:
#              Age Age_Code
# 3       0.750000     Year
# 15      0.583333     Year
# 23      0.416667     Year
# 132     0.916667     Year
# 438     0.916667     Year
# ...          ...      ...
# 137398  0.250000     Year
# 137399  0.500000     Year
# 137404  0.750000     Year
# 137651  0.416667     Year
# 137652  0.166667     Year
#
# [1118 rows x 2 columns]

# %%
#Create a new dataframe df3 where age_code is year 
df3=data[data['Age_Code'] =='Year']
print(df3)
# Out:
#          Age Age_Code
# 0       37.0     Year
# 1       17.0     Year
# 2       20.0     Year
# 4       19.0     Year
# 5       22.0     Year
# ...      ...      ...
# 137655  23.0     Year
# 137656  31.0     Year
# 137657  24.0     Year
# 137658   1.0     Year
# 137659  29.0     Year
#
# [136497 rows x 2 columns]

# %%
#concatenate df2 and df3 in new dataframe df4
df4 = pd.concat([df3,df2])

# %%
df4
# Out:
#               Age Age_Code
# 0       37.000000     Year
# 1       17.000000     Year
# 2       20.000000     Year
# 4       19.000000     Year
# 5       22.000000     Year
# ...           ...      ...
# 137398   0.250000     Year
# 137399   0.500000     Year
# 137404   0.750000     Year
# 137651   0.416667     Year
# 137652   0.166667     Year
#
# [137615 rows x 2 columns]

# %%
# selecting rows based on condition(age range between 0-3years) 
df5 = df4[(df4['Age'] >=0) &(df4['Age']<=3)]
print(df5)
# Out:
#              Age Age_Code
# 13      3.000000     Year
# 69      2.000000     Year
# 81      2.000000     Year
# 92      1.000000     Year
# 96      2.000000     Year
# ...          ...      ...
# 137398  0.250000     Year
# 137399  0.500000     Year
# 137404  0.750000     Year
# 137651  0.416667     Year
# 137652  0.166667     Year
#
# [7049 rows x 2 columns]

# %%
df5.hist()
plt.xlabel("age_groups")
plt.ylabel("number of peoples")
# Out:
# Text(0, 0.5, 'number of peoples')

# %%
plt.hist(df5['Age'])
plt.title('Age')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(data['Haemoglobin_level'], bins = 50)
plt.title('Blood haemoglobin')
plt.show

# %%
# selecting rows age range 4-18years
b = df4[(df4['Age'] >=4) &(df4['Age']<18)] 
print(b)
# Out:
#          Age Age_Code
# 1       17.0     Year
# 6        5.0     Year
# 8        5.0     Year
# 12       7.0     Year
# 18      15.0     Year
# ...      ...      ...
# 137633   8.0     Year
# 137634   7.0     Year
# 137640  17.0     Year
# 137641  11.0     Year
# 137642   9.0     Year
#
# [38362 rows x 2 columns]

# %%
b.hist()
plt.xlabel("age_groups")
plt.ylabel("number of peoples")
# Out:
# Text(0, 0.5, 'number of peoples')

# %%
# selecting rows age range 18-110 years
c = df4[(df4['Age'] >=18)&(df4['Age']<=110)]
print(c)
# Out:
#          Age Age_Code
# 0       37.0     Year
# 2       20.0     Year
# 4       19.0     Year
# 5       22.0     Year
# 7       47.0     Year
# ...      ...      ...
# 137654  18.0     Year
# 137655  23.0     Year
# 137656  31.0     Year
# 137657  24.0     Year
# 137659  29.0     Year
#
# [92193 rows x 2 columns]

# %%
c.hist()
plt.xlabel("age_groups")
plt.ylabel("number of peoples")
# Out:
# Text(0, 0.5, 'number of peoples')
